# %%
"""
PRIA version
Additive white Gaussian noise (AWGN)
"""
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard
import os
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np

# %%
def preprocess(array):
    """
    Normalizes the supplied array and reshapes it into the appropriate format.
    """
    # 需要進行 normalization，否則 binary_crossentropy loss 為負數
    array = array.astype("float32") / 255.0
    array = np.reshape(array, (len(array), 28, 28, 1))
    return array

def noise(array, noise_factor):
    """
    Adds random noise to each image in the supplied array.
    """

    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )

    return np.clip(noisy_array, 0.0, 1.0)

def display(array1, array2):
    """
    Displays ten random images from each one of the supplied arrays.
    """

    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
# Since we only need images from the dataset to encode and decode, we
# won't use the labels.
(train_data, _), (test_data, _) = mnist.load_data()

# Normalize and reshape the data
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# Create a copy of the data with added noise
noisy_train_data = noise(train_data, noise_factor=0.1)
noisy_test_data = noise(test_data, noise_factor=0.1)

# Display the train data and a version of it with added noise
display(train_data, noisy_train_data)

# %%
input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format
# 1x28x28
# Encoder 使用卷積層，激活函數用 relu，輸入的維度就是上面定義的 input_img
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
# 16@28x28
x = MaxPooling2D((2, 2), padding='same')(x)
# 16@14x14
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# 8@14X14
encoded = MaxPooling2D((2, 2), padding='same', name='encoder')(x)
# 8@7x7    
    
# Decoder 的過程與 Encoder 正好相反，需要跟 Encoder 的神經網絡層做相對應，相對應的激活函數也是一樣，
# 但這邊在解碼中最後一層使用的激活函數是 sigmoid
# 8@7x7    
x = UpSampling2D((2, 2))(encoded)
# 8@14X14
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
# 16@14X14
x = UpSampling2D((2, 2))(x)
# 16@28x28
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='decoder')(x)

    
# 用 Model 來搭建模型，輸入為圖片，輸出是解碼的結果
autoencoder = Model(input_img, decoded)  
    
# 編譯模型，optimizer 使用 adam，loss 使用 binary_crossentropy
opt = keras.optimizers.Adadelta(learning_rate=0.01) # 調高 learning_rate, Defaults to 0.001
autoencoder.compile(optimizer=opt, loss='binary_crossentropy')
    
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         1160
#
#  encoder (MaxPooling2D)      (None, 7, 7, 8)           0
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 8)        0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  decoder (Conv2D)            (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 2,633
# Trainable params: 2,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 訓練 Denoising AE
# This will train for 20 epochs
autoencoder.fit(noisy_train_data, train_data, epochs=20, batch_size=128, 
                shuffle=True, validation_data=(noisy_test_data, test_data), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001D61A6DAAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001D61A6DAAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 469/469 [==============================] - ETA: 0s - loss: 0.6373WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001D61AB0CEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001D61AB0CEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 469/469 [==============================] - 52s 109ms/step - loss: 0.6373 - val_loss: 0.5308
# Epoch 2/20
# 469/469 [==============================] - 40s 84ms/step - loss: 0.3259 - val_loss: 0.2040
# Epoch 3/20
# 469/469 [==============================] - 40s 85ms/step - loss: 0.1851 - val_loss: 0.1743
# Epoch 4/20
# 469/469 [==============================] - 43s 91ms/step - loss: 0.1694 - val_loss: 0.1631
# Epoch 5/20
# 469/469 [==============================] - 43s 93ms/step - loss: 0.1593 - val_loss: 0.1537
# Epoch 6/20
# 469/469 [==============================] - 43s 92ms/step - loss: 0.1505 - val_loss: 0.1453
# Epoch 7/20
# 469/469 [==============================] - 45s 96ms/step - loss: 0.1427 - val_loss: 0.1381
# Epoch 8/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.1362 - val_loss: 0.1323
# Epoch 9/20
# 469/469 [==============================] - 45s 96ms/step - loss: 0.1311 - val_loss: 0.1277
# Epoch 10/20
# 469/469 [==============================] - 46s 97ms/step - loss: 0.1270 - val_loss: 0.1241
# Epoch 11/20
# 469/469 [==============================] - 45s 97ms/step - loss: 0.1237 - val_loss: 0.1211
# Epoch 12/20
# 469/469 [==============================] - 44s 94ms/step - loss: 0.1209 - val_loss: 0.1185
# Epoch 13/20
# 469/469 [==============================] - 44s 93ms/step - loss: 0.1186 - val_loss: 0.1164
# Epoch 14/20
# 469/469 [==============================] - 44s 93ms/step - loss: 0.1166 - val_loss: 0.1145
# Epoch 15/20
# 469/469 [==============================] - 45s 96ms/step - loss: 0.1148 - val_loss: 0.1129
# Epoch 16/20
# 469/469 [==============================] - 45s 96ms/step - loss: 0.1133 - val_loss: 0.1115
# Epoch 17/20
# 469/469 [==============================] - 44s 94ms/step - loss: 0.1120 - val_loss: 0.1102
# Epoch 18/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.1108 - val_loss: 0.1091
# Epoch 19/20
# 469/469 [==============================] - 45s 96ms/step - loss: 0.1097 - val_loss: 0.1080
# Epoch 20/20
# 469/469 [==============================] - 44s 94ms/step - loss: 0.1087 - val_loss: 0.1071

# %%
predictions = autoencoder.predict(train_data)
display(noisy_train_data, predictions)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001D61AC56A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001D61AC56A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
# Create a copy of the data with added noise
noisy_train_data = noise(train_data, noise_factor=0.01)
noisy_test_data = noise(test_data, noise_factor=0.01)

# Display the train data and a version of it with added noise
display(train_data, noisy_train_data)

# %%
# 訓練 Denoising AE
# This will train for 20 epochs
autoencoder.fit(noisy_train_data, train_data, epochs=20, batch_size=128, 
                shuffle=True, validation_data=(noisy_test_data, test_data), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 63s 135ms/step - loss: 0.1064 - val_loss: 0.1048
# Epoch 2/20
# 469/469 [==============================] - 107s 227ms/step - loss: 0.1055 - val_loss: 0.1039
# Epoch 3/20
# 469/469 [==============================] - 95s 202ms/step - loss: 0.1047 - val_loss: 0.1031
# Epoch 4/20
# 469/469 [==============================] - 100s 214ms/step - loss: 0.1039 - val_loss: 0.1024
# Epoch 5/20
# 469/469 [==============================] - 89s 191ms/step - loss: 0.1032 - val_loss: 0.1017
# Epoch 6/20
# 469/469 [==============================] - 99s 211ms/step - loss: 0.1026 - val_loss: 0.1011
# Epoch 7/20
# 469/469 [==============================] - 101s 215ms/step - loss: 0.1019 - val_loss: 0.1005
# Epoch 8/20
# 469/469 [==============================] - 99s 211ms/step - loss: 0.1014 - val_loss: 0.0999
# Epoch 9/20
# 469/469 [==============================] - 100s 213ms/step - loss: 0.1008 - val_loss: 0.0994
# Epoch 10/20
# 469/469 [==============================] - 99s 211ms/step - loss: 0.1003 - val_loss: 0.0990
# Epoch 11/20
# 469/469 [==============================] - 101s 215ms/step - loss: 0.0999 - val_loss: 0.0985
# Epoch 12/20
# 469/469 [==============================] - 99s 212ms/step - loss: 0.0994 - val_loss: 0.0981
# Epoch 13/20
# 469/469 [==============================] - 98s 208ms/step - loss: 0.0990 - val_loss: 0.0977
# Epoch 14/20
# 469/469 [==============================] - 100s 213ms/step - loss: 0.0986 - val_loss: 0.0973
# Epoch 15/20
# 469/469 [==============================] - 100s 214ms/step - loss: 0.0982 - val_loss: 0.0970
# Epoch 16/20
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0979 - val_loss: 0.0966
# Epoch 17/20
# 469/469 [==============================] - 96s 204ms/step - loss: 0.0975 - val_loss: 0.0963
# Epoch 18/20
# 469/469 [==============================] - 97s 206ms/step - loss: 0.0972 - val_loss: 0.0960
# Epoch 19/20
# 469/469 [==============================] - 96s 204ms/step - loss: 0.0969 - val_loss: 0.0957
# Epoch 20/20
# 469/469 [==============================] - 97s 207ms/step - loss: 0.0966 - val_loss: 0.0953

# %%
predictions = autoencoder.predict(train_data)
display(noisy_train_data, predictions)
